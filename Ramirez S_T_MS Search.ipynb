# %%
import pandas as pd

# %%
First = pd.read_excel('Ramirez v. WDPR Coronado Springs Resort Slip Testing - 7_22_2010- 7_22_2015.xlsx')
Second = pd.read_excel('Ramirez v. WDPR Coronado Springs Resort Slip Testing - 7_23_2015- 4_22_2024.xlsx')
Claims = pd.read_excel('Ramirez v. WDPR Coronado Springs Resort Slip Testing - All Claim Numbers.xlsx')

# %%
First
# Out:
#   Claim Number Date of Incident       Claimant Name  \
# 0   G201016457       2010-10-01        Jones, Carla
# 1   G201021728       2010-12-31        Yarboro, Tim
# 2   G201213770       2012-06-25    Smith, Jeffrey R
# 3   G201226522       2012-12-06      Brines, Jordan
# 4   G201305378       2013-03-08   Digiorgio, Susan
# 5   G201316937       2013-06-16  Brickhouse, Donna
# 6   G201321031       2013-09-18     Ellis, Antonio
#
#                     Location Code Desc Sub Location Desc  \
# 0                  Ranchos Guest Rooms   Walkway Outside
# 1                  Casitas Guest Rooms   Walkway Outside
# 2                  Casitas Guest Rooms   Walkway Outside
# 3                  Ranchos Guest Rooms   Walkway Outside
# 4                  Casitas Guest Rooms   Walkway Outside
# 5                  Ranchos Guest Rooms   Walkway Outside
# 6  Laundry Facility - Coronado Springs   Walkway Outside
#
#                                 Incident Description  \
# ...

# %%
Second
# Out:
#       Claim Number Date of Incident        Claimant Name  \
# 0   WDWG2016110545       2016-08-12   Guthrie, Kimberly
# 1   WDWG2016111503       2016-08-23          Han, Robin
# 2   WDWG2016111828       2016-08-24       Taylor, Steve
# 3   WDWG2016116041       2016-10-06         Thorp, Mary
# 4   WDWG2016122765       2016-12-15        Boutin, Tina
# 5   WDWG2017144553       2017-06-27  Ricouard, Chadwick
# 6   WDWG2017154123       2017-09-23        Rhyne, Donna
# 7   WDWG2018167950       2018-01-25       Gerhard, Ryan
# 8   WDWG2018188362       2018-07-29       Gurdian, Raul
# 9   WDWG2018203609       2018-12-22     Gannon, Janice J
# 10  WDWG2019213857       2019-11-30    Cawthon, Connie J
# 11  WDWG2020637622       2020-10-29        Johnson, Amy
# 12  WDWG2022222190       2022-01-20   Collins, Cynthia J
#
#                   Location Code Desc  Sub Location Desc  \
# 0                Casitas Guest Rooms    Walkway Outside
# 1                Ranchos Guest Rooms    Walkway Outside
# ...

# %%
Claims
# Out:
#         Claim Number Date of Incident          Claimant Name  \
# 0         G201012552       2010-07-24           Faber, Keira
# 1         G201012734       2010-07-28       Southard, Amelia
# 2         G201013184       2010-08-03       Casillas, Martin
# 3         G201013187       2010-08-03        Piccolo, Sandra
# 4         G201013523       2010-08-09   Borrayo, Linda Marie
# ...              ...              ...                    ...
# 1346  WDWG2024743444       2024-03-28  Boyer, Jean Francois
# 1347  WDWG2024744086       2024-03-31          Silva, Maria
# 1348  WDWG2024744968       2024-04-07       Mullen, Abigail
# 1349  WDWG2024744695       2024-04-10          Ferrer, Ines
# 1350            1350              NaT                    NaN
#
#                         Location Code Desc  Sub Location Desc
# 0                                La Marina    Walkway Outside
# 1                      Casitas Guest Rooms  In Room - Bedroom
# ...

# %%
FirstSearch = First[First['Treatment Code (IAAPA) Desc'] == '1 Fatality']
