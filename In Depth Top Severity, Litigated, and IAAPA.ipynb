# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('Top Severity_Litigated_IAAPA - Analysis.xlsx')

# %%
def update_event_desc(value):
    if pd.notna(value) and 'Slip/Trip/Misstep' in value:
        return 'Slip/Trip/Misstep'
    return value

data['Event of Incident Desc'] = data['Event of Incident Desc'].apply(update_event_desc)

# %%
fy23data = data[data['Fiscal Year'] == 'FY23']

# %%
Severity_insights = fy23data.groupby(['Event of Incident Desc', 'Source of Incident Desc', 'Location Code Desc', 'Sub Location Desc'])[['Disney Claim Total Incurred', 'Claim Number']].agg({
    'Disney Claim Total Incurred': 'sum',
    'Claim Number': 'nunique'
}).reset_index()

# %%
Severity_event_source_combinations = Severity_insights.groupby(['Event of Incident Desc', 'Source of Incident Desc'])[['Disney Claim Total Incurred', 'Claim Number']].agg({
    'Disney Claim Total Incurred': 'sum',
    'Claim Number': 'sum'
}).nlargest(10, 'Disney Claim Total Incurred')

# %%
Severity_location_sublocations = []

#for idx, row in top_event_source_combinations.iterrows():
    #event_source_condition = (combined_insights['Event of Incident Desc'] == idx[0]) & (combined_insights['Source of Incident Desc'] == idx[1])
    #top_location_sublocations.append(combined_insights[event_source_condition].nlargest(5, 'Claim Number'))

for idx, row in Severity_event_source_combinations.iterrows():
    event_source_Severity = (Severity_insights['Event of Incident Desc'] == idx[0]) & (Severity_insights['Source of Incident Desc'] == idx[1])
    Severity_location_sublocations.append(Severity_insights[event_source_Severity].nlargest(5, 'Disney Claim Total Incurred'))

# Concatenate the DataFrames for top location and sublocation combinations
Severity_result = pd.concat(Severity_location_sublocations)
Severity_result
# Out:
#       Event of Incident Desc  \
# 15193      Slip/Trip/Misstep
# 15673      Slip/Trip/Misstep
# 15168      Slip/Trip/Misstep
# 15484      Slip/Trip/Misstep
# 15709      Slip/Trip/Misstep
# 14564      Slip/Trip/Misstep
# 14578      Slip/Trip/Misstep
# 14347      Slip/Trip/Misstep
# 14651      Slip/Trip/Misstep
# 14594      Slip/Trip/Misstep
# 19461       Struck/Struck By
# 19408       Struck/Struck By
# 19336       Struck/Struck By
# 19337       Struck/Struck By
# 19338       Struck/Struck By
# 16488      Slip/Trip/Misstep
# 16367      Slip/Trip/Misstep
# 16418      Slip/Trip/Misstep
# 16346      Slip/Trip/Misstep
# 16523      Slip/Trip/Misstep
# 12793      Slip/Trip/Misstep
# 12828      Slip/Trip/Misstep
# 12735      Slip/Trip/Misstep
# 12805      Slip/Trip/Misstep
# 12777      Slip/Trip/Misstep
# 10187  On Ride - Ride Motion
# 10150  On Ride - Ride Motion
# 10127  On Ride - Ride Motion
# 10116  On Ride - Ride Motion
# 10177  On Ride - Ride Motion
# 16027      Slip/Trip/Misstep
# 16039      Slip/Trip/Misstep
# 16112      Slip/Trip/Misstep
# 16109      Slip/Trip/Misstep
# 16149      Slip/Trip/Misstep
# 2512         Eating/Drinking
# 2362         Eating/Drinking
# 2450         Eating/Drinking
# 2677         Eating/Drinking
# 2438         Eating/Drinking
# 20617                Unknown
# 20613                Unknown
# 20684                Unknown
# 20676                Unknown
# 20657                Unknown
# 13299      Slip/Trip/Misstep
# 13300      Slip/Trip/Misstep
# 13295      Slip/Trip/Misstep
# 13291      Slip/Trip/Misstep
# 13294      Slip/Trip/Misstep
#
#                                  Source of Incident Desc  \
# 15193                          Walking Surface - Outdoor
# 15673                          Walking Surface - Outdoor
# 15168                          Walking Surface - Outdoor
# 15484                          Walking Surface - Outdoor
# 15709                          Walking Surface - Outdoor
# 14564                           Walking Surface - Indoor
# 14578                           Walking Surface - Indoor
# 14347                           Walking Surface - Indoor
# 14651                           Walking Surface - Indoor
# 14594                           Walking Surface - Indoor
# 19461      Permanent Structures - Handrail/Railing/Fence
# 19408      Permanent Structures - Handrail/Railing/Fence
# 19336      Permanent Structures - Handrail/Railing/Fence
# 19337      Permanent Structures - Handrail/Railing/Fence
# 19338      Permanent Structures - Handrail/Railing/Fence
# 16488             Walking Surface - Outdoor - Stair/Step
# 16367             Walking Surface - Outdoor - Stair/Step
# 16418             Walking Surface - Outdoor - Stair/Step
# 16346             Walking Surface - Outdoor - Stair/Step
# 16523             Walking Surface - Outdoor - Stair/Step
# 12793  Attraction Related - Park Vehicle - Attraction...
# 12828  Attraction Related - Park Vehicle - Attraction...
# 12735  Attraction Related - Park Vehicle - Attraction...
# 12805  Attraction Related - Park Vehicle - Attraction...
# 12777  Attraction Related - Park Vehicle - Attraction...
# 10187  Attraction Related - Park Vehicle - Attraction...
# 10150  Attraction Related - Park Vehicle - Attraction...
# 10127  Attraction Related - Park Vehicle - Attraction...
# 10116  Attraction Related - Park Vehicle - Attraction...
# 10177  Attraction Related - Park Vehicle - Attraction...
# 16027                   Walking Surface - Outdoor - Curb
# 16039                   Walking Surface - Outdoor - Curb
# 16112                   Walking Surface - Outdoor - Curb
# 16109                   Walking Surface - Outdoor - Curb
# 16149                   Walking Surface - Outdoor - Curb
# 2512   Food/Drink and Related Items - Food Item/Beverage
# 2362   Food/Drink and Related Items - Food Item/Beverage
# 2450   Food/Drink and Related Items - Food Item/Beverage
# 2677   Food/Drink and Related Items - Food Item/Beverage
# 2438   Food/Drink and Related Items - Food Item/Beverage
# 20617                                            Unknown
# 20613                                            Unknown
# 20684                                            Unknown
# 20676                                            Unknown
# 20657                                            Unknown
# 13299  Furnishings/Fixtures/Decorations - Rack/Shelf/...
# 13300  Furnishings/Fixtures/Decorations - Rack/Shelf/...
# 13295  Furnishings/Fixtures/Decorations - Rack/Shelf/...
# 13291  Furnishings/Fixtures/Decorations - Rack/Shelf/...
# 13294  Furnishings/Fixtures/Decorations - Rack/Shelf/...
#
#                                Location Code Desc  \
# 15193                  Bus Stop - All-Star Sports
# 15673                   North Quarter Guest Rooms
# 15168          Big Bear Path and Little Bear Path
# 15484       Guest Relations - Animal Kingdom Park
# 15709                  Parking Lot - Contemporary
# 14564                      Great Ceremonial House
# 14578                  Guest Rooms - Old Key West
# 14347                         Atlantic Dance Club
# 14651                          Lobby - Beach Club
# 14594             Guest Rooms Unknown - Riverside
# 19461                     Waggin' Trails Dog Park
# 19408                  Magic Kingdom Bus Facility
# 19336                        "it's a small world"
# 19337                               Adventureland
# 19338                      Alien Swirling Saucers
# 16488                                       Italy
# 16367                        Barbados Guest Rooms
# 16418               Disney's Animal Kingdom Lodge
# 16346                  101 Dalmatians Guest Rooms
# 16523                                      Mexico
# 12793                    Pirates of the Caribbean
# 12828                  Tomorrowland Indy Speedway
# 12735          Buzz Lightyear's Space Ranger Spin
# 12805  Rock 'n' Roller Coaster Starring Aerosmith
# 12777                               Mad Tea Party
# 10187          Twilight Zone Tower of Terror, The
# 10150                          Peter Pan's Flight
# 10127                         Kilimanjaro Safaris
# 10116      Guardians of the Galaxy: Cosmic Rewind
# 10177                         TRON Lightcycle Run
# 16027                     Bus Stop - Old Key West
# 16039                               Computer Pool
# 16112                         Main Street, U.S.A.
# 16109                   Main Street Confectionery
# 16149        Sassagoula Floatworks & Food Factory
# 2512        Disney's Grand Floridian Resort & Spa
# 2362         American Adventure, The (Attraction)
# 2450                           Connections Eatery
# 2677                          Liberty Tree Tavern
# 2438                     Cinderella's Royal Table
# 20617                              Disney Springs
# 20613                         Crystal Palace, The
# 20684                      Other On Property Area
# 20676                          Magic Kingdom Park
# 20657                             Grand Slam Pool
# 13299                       Orange Parking Garage
# 13300                       Orange Parking Garage
# 13295                         Lime Parking Garage
# 13291                              Disney Springs
# 13294                         Lime Parking Garage
#
#                         Sub Location Desc  Disney Claim Total Incurred  \
# 15193                     Walkway Outside                    135000.00
# 15673                     Walkway Outside                    128000.00
# 15168                           In Camper                     85000.00
# 15484                     Walkway Outside                     85000.00
# 15709                             Walkway                     78000.00
# 14564                      Walkway Inside                    193500.00
# 14578                  In Room - Bathroom                    150825.00
# 14347                         Dance Floor                    102500.00
# 14651                      Walkway Inside                    100000.00
# 14594                   In Room - Bedroom                     65000.00
# 19461                      Walkway Nearby                    701000.00
# 19408                          Queue Line                      2986.55
# 19336                          Queue Line                         0.00
# 19337                            Walkways                         0.00
# 19338                          Queue Line                         0.00
# 16488                            Walkways                    121250.00
# 16367                     Walkway Outside                     85000.00
# 16418                            Walkways                     78000.00
# 16346                          Stairwells                     75000.00
# 16523                            Walkways                     23000.00
# 12793                                Load                    161407.90
# 12828                              Unload                     80020.00
# 12735                              Unload                     61000.00
# 12805                                Load                     60000.00
# 12777                              Unload                     20034.14
# 10187                             On Ride                    150900.00
# 10150                             On Ride                    100000.00
# 10127                             On Ride                     35000.00
# 10116                             On Ride                     22976.73
# 10177                             On Ride                     14100.90
# 16027                     Walkway Outside                    101500.00
# 16039                        Seating Area                     75000.00
# 16112                            Walkways                     26000.00
# 16109                     Walkway Outside                     25000.00
# 16149                     Walkway Outside                     20000.00
# 2512   Food and Beverage/Merchandise Cart                     60000.00
# 2362                 Preshow/Waiting Room                     25828.00
# 2450                  Dining/Seating Area                     19300.00
# 2677                  Dining/Seating Area                     17453.32
# 2438                  Dining/Seating Area                     16125.18
# 20617                             Unknown                     85000.00
# 20613                 Dining/Seating Area                     65000.00
# 20684                             Unknown                     60000.00
# 20676                            Walkways                     50000.00
# 20657                             Unknown                     15000.00
# 13299       Security Kiosk/Security Gates                    151000.00
# 13300                             Walkway                    101000.00
# 13295       Security Kiosk/Security Gates                     26750.00
# 13291                            Walkways                     20000.00
# 13294                              In Lot                     15000.00
#
#        Claim Number
# 15193             1
# 15673             4
# 15168             1
# 15484             4
# 15709             1
# 14564             7
# 14578             2
# 14347             1
# 14651             1
# 14594             1
# 19461             1
# 19408             1
# 19336             1
# 19337             1
# 19338             1
# 16488             4
# 16367             2
# 16418             2
# 16346             1
# 16523             9
# 12793            17
# 12828            96
# 12735            12
# 12805             4
# 12777            20
# 10187            83
# 10150            24
# 10127            54
# 10116           739
# 10177           106
# 16027             2
# 16039             1
# 16112            61
# 16109             4
# 16149             3
# 2512              5
# 2362            128
# 2450             17
# 2677             42
# 2438             45
# 20617             4
# 20613             1
# 20684             6
# 20676             4
# 20657             1
# 13299             7
# 13300             1
# 13295            11
# 13291             5
# 13294             3

# %%
Litigatedfy23 = fy23data[fy23data['Attorney Represented'] == 'Y']

# %%
Litigated_insights = Litigatedfy23.groupby(['Event of Incident Desc', 'Source of Incident Desc', 'Location Code Desc', 'Sub Location Desc'])[['Disney Claim Total Incurred', 'Claim Number']].agg({
    'Disney Claim Total Incurred': 'sum',
    'Claim Number': 'nunique'
}).reset_index()

# %%
Litigated_event_source_combinations = Litigated_insights.groupby(['Event of Incident Desc', 'Source of Incident Desc'])[['Disney Claim Total Incurred', 'Claim Number']].agg({
    'Disney Claim Total Incurred': 'sum',
    'Claim Number': 'sum'
}).nlargest(10, 'Claim Number')

# %%
Litigated_location_sublocations = []

#for idx, row in top_event_source_combinations.iterrows():
    #event_source_condition = (combined_insights['Event of Incident Desc'] == idx[0]) & (combined_insights['Source of Incident Desc'] == idx[1])
    #top_location_sublocations.append(combined_insights[event_source_condition].nlargest(5, 'Claim Number'))

for idx, row in Litigated_event_source_combinations.iterrows():
    event_source_Litigated = (Litigated_insights['Event of Incident Desc'] == idx[0]) & (Litigated_insights['Source of Incident Desc'] == idx[1])
    Litigated_location_sublocations.append(Litigated_insights[event_source_Litigated].nlargest(5, 'Claim Number'))

# Concatenate the DataFrames for top location and sublocation combinations
Litigated_result = pd.concat(Litigated_location_sublocations)
Litigated_result
# Out:
#     Event of Incident Desc                            Source of Incident Desc  \
# 321                Unknown                                            Unknown
# 317                Unknown                                            Unknown
# 305                Unknown                                            Unknown
# 309                Unknown                                            Unknown
# 320                Unknown                                            Unknown
# 211      Slip/Trip/Misstep                          Walking Surface - Outdoor
# 184      Slip/Trip/Misstep                          Walking Surface - Outdoor
# 185      Slip/Trip/Misstep                          Walking Surface - Outdoor
# 186      Slip/Trip/Misstep                          Walking Surface - Outdoor
# 187      Slip/Trip/Misstep                          Walking Surface - Outdoor
# 156      Slip/Trip/Misstep                           Walking Surface - Indoor
# 157      Slip/Trip/Misstep                           Walking Surface - Indoor
# 158      Slip/Trip/Misstep                           Walking Surface - Indoor
# 159      Slip/Trip/Misstep                           Walking Surface - Indoor
# 160      Slip/Trip/Misstep                           Walking Surface - Indoor
# 244      Slip/Trip/Misstep             Walking Surface - Outdoor - Stair/Step
# 233      Slip/Trip/Misstep             Walking Surface - Outdoor - Stair/Step
# 234      Slip/Trip/Misstep             Walking Surface - Outdoor - Stair/Step
# 235      Slip/Trip/Misstep             Walking Surface - Outdoor - Stair/Step
# 236      Slip/Trip/Misstep             Walking Surface - Outdoor - Stair/Step
# 64   On Ride - Ride Motion  Attraction Related - Park Vehicle - Attraction...
# 59   On Ride - Ride Motion  Attraction Related - Park Vehicle - Attraction...
# 58   On Ride - Ride Motion  Attraction Related - Park Vehicle - Attraction...
# 60   On Ride - Ride Motion  Attraction Related - Park Vehicle - Attraction...
# 61   On Ride - Ride Motion  Attraction Related - Park Vehicle - Attraction...
# 97       Slip/Trip/Misstep  Attraction Related - Park Vehicle - Attraction...
# 100      Slip/Trip/Misstep  Attraction Related - Park Vehicle - Attraction...
# 94       Slip/Trip/Misstep  Attraction Related - Park Vehicle - Attraction...
# 95       Slip/Trip/Misstep  Attraction Related - Park Vehicle - Attraction...
# 96       Slip/Trip/Misstep  Attraction Related - Park Vehicle - Attraction...
# 227      Slip/Trip/Misstep           Walking Surface - Outdoor - Parking Curb
# 228      Slip/Trip/Misstep           Walking Surface - Outdoor - Parking Curb
# 226      Slip/Trip/Misstep           Walking Surface - Outdoor - Parking Curb
# 229      Slip/Trip/Misstep           Walking Surface - Outdoor - Parking Curb
# 230      Slip/Trip/Misstep           Walking Surface - Outdoor - Parking Curb
# 274       Struck/Struck By                   Motor Vehicle - Third Party Auto
# 275       Struck/Struck By                   Motor Vehicle - Third Party Auto
# 276       Struck/Struck By                   Motor Vehicle - Third Party Auto
# 277       Struck/Struck By                   Motor Vehicle - Third Party Auto
# 14         Eating/Drinking  Food/Drink and Related Items - Food Item/Beverage
# 15         Eating/Drinking  Food/Drink and Related Items - Food Item/Beverage
# 16         Eating/Drinking  Food/Drink and Related Items - Food Item/Beverage
# 17         Eating/Drinking  Food/Drink and Related Items - Food Item/Beverage
# 18         Eating/Drinking  Food/Drink and Related Items - Food Item/Beverage
# 69   On Ride - Ride Motion                       Motor Vehicle - Bus - Disney
# 67   On Ride - Ride Motion                       Motor Vehicle - Bus - Disney
# 68   On Ride - Ride Motion                       Motor Vehicle - Bus - Disney
# 70   On Ride - Ride Motion                       Motor Vehicle - Bus - Disney
#
#                              Location Code Desc  \
# 321                      Other On Property Area
# 317                          Magic Kingdom Park
# 305                              Disney Springs
# 309                  Disney's Hollywood Studios
# 320                     Other Off Property Area
# 211                Remy's Ratatouille Adventure
# 184             Backstage Areas - Magic Kingdom
# 185          Big Bear Path and Little Bear Path
# 186                  Bus Stop - All-Star Sports
# 187                         Calypso Guest Rooms
# 156                 Alligator Bayou Guest Rooms
# 157                         Atlantic Dance Club
# 158           Auntie Gravity's Galactic Goodies
# 159                                   Club Cool
# 160             Disney's Caribbean Beach Resort
# 244                                       Italy
# 233                  101 Dalmatians Guest Rooms
# 234  AdventHealth Waterside Stage - Marketplace
# 235                        Barbados Guest Rooms
# 236          Buzz Lightyear's Space Ranger Spin
# 64           Twilight Zone Tower of Terror, The
# 59                          Kilimanjaro Safaris
# 58       Guardians of the Galaxy: Cosmic Rewind
# 60                           Peter Pan's Flight
# 61                      Seven Dwarfs Mine Train
# 97                     Pirates of the Caribbean
# 100                  Tomorrowland Indy Speedway
# 94                     Liberty Square Riverboat
# 95                         Marketplace Carousel
# 96                           Peter Pan's Flight
# 227                         Parking Lot - Epcot
# 228             Parking Lot - Hollywood Studios
# 226               Parking Lot - Caribbean Beach
# 229                 Parking Lot - Magic Kingdom
# 230                       Parking Lot - Riviera
# 274                           Roadway - Overall
# 275              Speedway Gas Station Boardwalk
# 276                          Ticket Booth - TTC
# 277                                 World Drive
# 14                                       'Ohana
# 15                     Cinderella's Royal Table
# 16        Disney's Grand Floridian Resort & Spa
# 17                                        Epcot
# 18                        Le Cellier Steakhouse
# 69                            Roadway - Overall
# 67                            Buena Vista Drive
# 68                        Bus Stop - Polynesian
# 70                                  World Drive
#
#                       Sub Location Desc  Disney Claim Total Incurred  \
# 321                             Unknown                      60000.0
# 317                             Unknown                       2500.0
# 305                             Unknown                      85000.0
# 309                             Unknown                          0.0
# 320                             Unknown                       7500.0
# 211         Queue Line - LIGHTNING LANE                      11500.0
# 184                             Walkway                       5000.0
# 185                           In Camper                      85000.0
# 186                     Walkway Outside                     135000.0
# 187                     Walkway Outside                      25250.0
# 156                  In Room - Bathroom                       5000.0
# 157                         Dance Floor                     102500.0
# 158                Counter/Service Area                      10000.0
# 159                            Walkways                       8500.0
# 160                            Restroom                          0.0
# 244                            Walkways                     121250.0
# 233                          Stairwells                      75000.0
# 234                   In front of stage                      10000.0
# 235                     Walkway Outside                      85000.0
# 236                          Queue Line                       5000.0
# 64                              On Ride                      75000.0
# 59                              On Ride                      32500.0
# 58                              On Ride                      15000.0
# 60                              On Ride                     100000.0
# 61                              On Ride                          0.0
# 97                                 Load                     160000.0
# 100                              Unload                      65000.0
# 94                 On Ride - First Deck                      10000.0
# 95                       Other Location                          0.0
# 96                                 Load                      15000.0
# 227                               Moana                        750.0
# 228                             Walkway                          0.0
# 226                             Walkway                          0.0
# 229                        Disabled Lot                       5000.0
# 230                       Guest Parking                      25000.0
# 274                    In Other Vehicle                          0.0
# 275                      Other Location                          0.0
# 276                           Backstage                          0.0
# 277                    In Other Vehicle                          0.0
# 14                  Dining/Seating Area                       3000.0
# 15                  Dining/Seating Area                      15000.0
# 16   Food and Beverage/Merchandise Cart                      60000.0
# 17   Food and Beverage/Merchandise Cart                          0.0
# 18                  Dining/Seating Area                          0.0
# 69                      On Bus - Disney                     157500.0
# 67                      On Bus - Disney                      25000.0
# 68                               On Bus                      15000.0
# 70                      On Bus - Disney                          0.0
#
#      Claim Number
# 321             5
# 317             4
# 305             3
# 309             2
# 320             2
# 211             2
# 184             1
# 185             1
# 186             1
# 187             1
# 156             1
# 157             1
# 158             1
# 159             1
# 160             1
# 244             2
# 233             1
# 234             1
# 235             1
# 236             1
# 64              3
# 59              2
# 58              1
# 60              1
# 61              1
# 97              2
# 100             2
# 94              1
# 95              1
# 96              1
# 227             2
# 228             2
# 226             1
# 229             1
# 230             1
# 274             4
# 275             2
# 276             1
# 277             1
# 14              1
# 15              1
# 16              1
# 17              1
# 18              1
# 69              3
# 67              2
# 68              1
# 70              1

# %%
Litigatedfy23 = fy23data[fy23data['Attorney Represented'] == 'Y']
Litigated = Litigatedfy23.groupby(['Event of Incident Desc', 'Source of Incident Desc'])[['Disney Claim Total Incurred', 'Claim Number']].agg({'Disney Claim Total Incurred': 'sum', 'Claim Number': 'nunique'}).nlargest(20, 'Claim Number')

# %%
Litigated
Litigated.reset_index(inplace=True)

# %%
IAAPA1 = fy23data[fy23data['Treatment Code (IAAPA) Desc'] == '1 Fatality']
IAAPA2 = fy23data[fy23data['Treatment Code (IAAPA) Desc'] == '2 Serious- Immed Hosp Adm & 24 Hour Stay']
IAAPA3 = fy23data[fy23data['Treatment Code (IAAPA) Desc'] == '3 Other Injury - LT Serious']
IAAPA4 = fy23data[fy23data['Treatment Code (IAAPA) Desc'] == '4 First Aid Only']
IAAPA5 = fy23data[fy23data['Treatment Code (IAAPA) Desc'] == '5 No Treatment']
IAAPA6 = fy23data[fy23data['Treatment Code (IAAPA) Desc'] == '6 Non-Injury Report']

# %%
IAAPA1 = IAAPA1.groupby(['Event of Incident Desc', 'Source of Incident Desc'])[['Disney Claim Total Incurred', 'Claim Number']].agg({'Disney Claim Total Incurred': 'sum', 'Claim Number': 'nunique'}).nlargest(20, 'Claim Number')
IAAPA1
IAAPA1.reset_index(inplace=True)

# %%
IAAPA2 = IAAPA2.groupby(['Event of Incident Desc', 'Source of Incident Desc'])[['Disney Claim Total Incurred', 'Claim Number']].agg({'Disney Claim Total Incurred': 'sum', 'Claim Number': 'nunique'}).nlargest(20, 'Claim Number')
IAAPA2
IAAPA2.reset_index(inplace=True)

# %%
IAAPA3 = IAAPA3.groupby(['Event of Incident Desc', 'Source of Incident Desc'])[['Disney Claim Total Incurred', 'Claim Number']].agg({'Disney Claim Total Incurred': 'sum', 'Claim Number': 'nunique'}).nlargest(20, 'Claim Number')
IAAPA3
IAAPA3.reset_index(inplace=True)

# %%
IAAPA4 = IAAPA4.groupby(['Event of Incident Desc', 'Source of Incident Desc'])[['Disney Claim Total Incurred', 'Claim Number']].agg({'Disney Claim Total Incurred': 'sum', 'Claim Number': 'nunique'}).nlargest(20, 'Claim Number')
IAAPA4
IAAPA4.reset_index(inplace=True)

# %%
IAAPA5 = IAAPA5.groupby(['Event of Incident Desc', 'Source of Incident Desc'])[['Disney Claim Total Incurred', 'Claim Number']].agg({'Disney Claim Total Incurred': 'sum', 'Claim Number': 'nunique'}).nlargest(20, 'Claim Number')
IAAPA5
IAAPA5.reset_index(inplace=True)

# %%
IAAPA6 = IAAPA6.groupby(['Event of Incident Desc', 'Source of Incident Desc'])[['Disney Claim Total Incurred', 'Claim Number']].agg({'Disney Claim Total Incurred': 'sum', 'Claim Number': 'nunique'}).nlargest(20, 'Claim Number')
IAAPA6
IAAPA6.reset_index(inplace=True)

# %%
output_path = r'J:\Data\RMSA Analysis\0 - Team Working Files\10 - Nick\Top_Severity_Litigated_IAAPA_Export.xlsx'

with pd.ExcelWriter(output_path, engine='xlsxwriter') as writer:

    # Write each DataFrame to a different worksheet
    Severity.to_excel(writer, sheet_name='Severity')
    Litigated.to_excel(writer, sheet_name='Litigated')
    IAAPA1.to_excel(writer, sheet_name='IAAPA1')
    IAAPA2.to_excel(writer, sheet_name='IAAPA2')
    IAAPA3.to_excel(writer, sheet_name='IAAPA3')
    IAAPA4.to_excel(writer, sheet_name='IAAPA4')
    IAAPA5.to_excel(writer, sheet_name='IAAPA5')
    IAAPA6.to_excel(writer, sheet_name='IAAPA6')
