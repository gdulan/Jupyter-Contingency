# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from transformers import AutoTokenizer, AutoModel
import torch
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.utils import resample
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
data = pd.read_excel('WCMLDataset.xlsx')

# %%
example_data = data

# %%
text_fields = [
    'Incident Description',
    'Activity Engaged in During Accident',
    'General HS Comments',
    'Injury Description'
]
example_data[text_fields] = example_data[text_fields].fillna('')

# %%
# Step 1: Data Cleaning and Preprocessing
def preprocess_text(text):
    """Basic text preprocessing: lowercasing and stripping whitespace."""
    if not isinstance(text, str):
        text = str(text)  # Convert to string if not already
    return text.lower().strip()

# Combine relevant input fields into a single text column
example_data['Combined_Text'] = (
    example_data['Incident Description'] + ' ' +
    example_data['Activity Engaged in During Accident'] + ' ' +
    example_data['General HS Comments'] + ' ' +
    example_data['Injury Description']
).apply(preprocess_text)

# Encode categorical output labels for modeling
from sklearn.preprocessing import LabelEncoder

output_fields = [
    'Source of Incident Desc',
    'Source of Injury Desc',
    'Event of Incident Desc',
    'Event of Injury Desc',
    'EDI Cause Desc'
]

label_encoders = {}
for field in output_fields:
    le = LabelEncoder()
    example_data[field + '_Encoded'] = le.fit_transform(example_data[field])
    label_encoders[field] = le  # Save encoders for inverse transformation later

example_data[['Combined_Text'] + [f"{field}_Encoded" for field in output_fields]].head()
# Out:
#                                        Combined_Text  \
# 0  a guest grabbed her wrist and pulled as she co...
# 1  he was kicked in the knee when a male guest go...
# 2  while performing housekeep duties she felt a b...
# 3  while feeding treats to a red river hog from t...
# 4  while eating the lettuce the turtle bit down o...
#
#    Source of Incident Desc_Encoded  Source of Injury Desc_Encoded  \
# 0                              133                            134
# 1                              133                            134
# 2                                1                              1
# 3                                2                              2
# 4                                2                              2
#
#    Event of Incident Desc_Encoded  Event of Injury Desc_Encoded  \
# 0                               0                             0
# 1                               0                             0
# 2                               2                             2
# 3                               2                             2
# 4                               2                             2
#
#    EDI Cause Desc_Encoded
# 0                       9
# 1                       9
# 2                       9
# 3                       9
# 4                       9

# %%
# Step 2: Initialize and apply the TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer(max_features=1500)  # Adjust max_features as needed
X_tfidf = tfidf_vectorizer.fit_transform(example_data['Combined_Text'])


print("TF-IDF matrix shape:", X_tfidf.shape)

print("Sample TF-IDF feature names:", tfidf_vectorizer.get_feature_names_out()[:10])
# Out:
# TF-IDF matrix shape: (8189, 1500)
# Sample TF-IDF feature names: ['00068470' '00138038' '00141918' '00214808' '00255032' '00338210'
#  '00339378' '00465407' '00575844' '00585371']

# %%
unique_classes = sorted(set(y_test))

report = classification_report(
    y_test, 
    y_pred, 
    labels=unique_classes,  
    target_names=[label_encoders['Source of Incident Desc'].inverse_transform([cls])[0] for cls in unique_classes]
)

print(report)
# Out:
#                                                                             precision    recall  f1-score   support
#
#                            Animal/Insect - Displayed (Petting Farm, Caged)       0.00      0.00      0.00         1
#                                             Animal/Insect - Domestic - Dog       0.00      0.00      0.00         1
#                                           Animal/Insect - Domestic - Horse       1.00      1.00      1.00         3
#                                                     Animal/Insect - Insect       0.82      0.88      0.85        51
#                                                       Animal/Insect - Wild       0.00      0.00      0.00         1
#                                                                  Appliance       0.33      0.50      0.40         4
#                                                   Appliance - Refrigerator       0.14      0.50      0.22         2
#                                                          Appliance - Stove       0.00      0.00      0.00         3
#                                                         Attraction Related       0.17      0.33      0.22         3
#                                           Attraction Related - Moving Belt       0.00      0.00      0.00         1
#                                          Attraction Related - Park Vehicle       0.00      0.00      0.00         1
#                     Attraction Related - Park Vehicle - Attraction Vehicle       0.60      0.43      0.50        14
#                                      Attraction Related - Safety Restraint       0.50      1.00      0.67         1
#                            Attraction Related - Safety Restraint - Lap Bar       0.50      1.00      0.67         1
#                                       Attraction Related - Stanchion Poles       0.67      1.00      0.80         4
#                                     Attraction Related - Water Slide/Flume       0.00      0.00      0.00         1
#                              Building/Cruise Ship - Bathroom - Toilet/Sink       0.50      0.50      0.50         2
#                               Building/Cruise Ship - Bathroom - Tub/Shower       0.27      0.80      0.40         5
#                                                Building/Cruise Ship - Door       0.76      0.70      0.73        50
#                                   Building/Cruise Ship - Lighting Fixtures       0.20      1.00      0.33         1
#                                             Building/Cruise Ship - Windows       0.00      0.00      0.00         1
#                                                                   COVID-19       0.38      1.00      0.55         3
#                                                           Cable/Chain/Rope       0.33      0.25      0.29         4
#                                              Cable/Chain/Rope - Queue Line       0.00      0.00      0.00         1
#                                                       Clothing/Accessories       0.50      0.33      0.40         9
#                                             Clothing/Accessories - Costume       0.72      0.69      0.70        48
#                                               Clothing/Accessories - Shoes       0.13      0.50      0.21         6
#                             Electrical - Electric Wiring Light/Power Cords       0.40      0.29      0.33         7
#                                                                Environment       0.00      0.00      0.00         2
#                                                  Environment - Air Quality       0.33      0.50      0.40         6
#                                           Environment - Air Quality - Dust       0.08      0.33      0.12         3
#                                           Environment - Air Quality - Mold       0.00      0.00      0.00         1
#                                                        Environment - Noise       0.62      0.71      0.67         7
#                                                   Environment - Rock/Stone       0.67      0.67      0.67         3
#                                                        Environment - Smoke       0.25      1.00      0.40         1
#                                             Environment - Trees and Plants       0.00      0.00      0.00         4
#                                                 Environment - Water/Liquid       0.11      0.20      0.14        10
#                                           Environment - Weather Conditions       0.33      0.60      0.43         5
#                                                                  Equipment       0.14      0.07      0.09        29
#                                                      Equipment - Hand Tool       0.06      0.07      0.06        15
#                                 Equipment - Hand Tool - Hand Tool Electric       0.00      0.00      0.00         1
#                              Equipment - Hand Tool - Hand Tool Nonelectric       0.06      0.50      0.11         2
#                                                     Equipment - Industrial       0.14      0.29      0.19         7
#                                          Equipment - Industrial - Forklift       0.40      1.00      0.57         2
#                                       Equipment - Industrial - Landscaping       0.00      0.00      0.00         4
#                                                Equipment - Scaffold/Ladder       0.75      1.00      0.86         9
#                                               Food/Drink and Related Items       0.62      0.07      0.13        67
#                                Food/Drink and Related Items - Buffet Trays       0.35      0.88      0.50        16
#                          Food/Drink and Related Items - Food Item/Beverage       0.54      0.18      0.27        39
#                             Food/Drink and Related Items - Plate/Cup/Glass       0.31      0.67      0.42         6
#                                    Food/Drink and Related Items - Utensils       0.29      0.31      0.30        13
#                                           Furnishings/Fixtures/Decorations       0.29      0.22      0.25         9
#                               Furnishings/Fixtures/Decorations - Furniture       0.83      0.19      0.30        27
#                         Furnishings/Fixtures/Decorations - Furniture - Bed       0.65      0.92      0.77        53
#                       Furnishings/Fixtures/Decorations - Furniture - Chair       0.59      0.81      0.68        16
#                       Furnishings/Fixtures/Decorations - Furniture - Table       0.19      0.60      0.29         5
#              Furnishings/Fixtures/Decorations - Garbage Can / Towel Return       0.10      1.00      0.18         4
#                              Furnishings/Fixtures/Decorations - High Chair       0.00      0.00      0.00         1
#                   Furnishings/Fixtures/Decorations - Paper Towel Dispenser       0.00      0.00      0.00         1
# Furnishings/Fixtures/Decorations - Planter/Retaining Wall/Concrete Barrier       0.00      0.00      0.00         3
#                         Furnishings/Fixtures/Decorations - Rack/Shelf/Case       0.36      0.53      0.43        17
#                             Furnishings/Fixtures/Decorations - Sign/Banner       0.25      1.00      0.40         1
#                                                                    Machine       0.00      0.00      0.00         3
#                                             Machine/Equipment - Stationary       0.08      1.00      0.14         1
#                                                              Motor Vehicle       0.00      0.00      0.00         3
#                                               Motor Vehicle - Bus - Disney       0.56      0.94      0.70        16
#                                  Motor Vehicle - Bus - Wheelchair/ECV Ramp       0.67      0.67      0.67         3
#                                                Motor Vehicle - Disney Auto       0.36      0.36      0.36        11
#                                         Motor Vehicle - Disney Auto - Door       0.00      0.00      0.00         2
#                                           Motor Vehicle - Third Party Auto       0.40      0.67      0.50         3
#                                                       Motor Vehicle - Tram       0.67      0.67      0.67         3
#                                                                    Objects       0.00      0.00      0.00       196
#                                             Objects - Bath & Body Products       0.29      0.33      0.31         6
#                                                   Objects - Cart/Bin/Dolly       0.69      0.68      0.69        66
#                                                      Objects - Glass Shard       0.69      0.90      0.78        10
#                                                            Objects - Heavy       0.21      0.57      0.31        23
#                                                          Objects - Ink Tag       0.00      0.00      0.00         1
#                                        Objects - Luggage/Suitcase/Backpack       0.60      0.50      0.55         6
#                                                       Objects - Nail/Screw       0.00      0.00      0.00         1
#                                                         Objects - Umbrella       0.25      1.00      0.40         1
#                                                      Other Transport - ECV       0.40      0.50      0.44        12
#                                             Other Transport - ECV - Disney       0.00      0.00      0.00         2
#                                        Other Transport - ECV - Third Party       0.33      0.23      0.27        13
#                              Other Transport - Electric Cart (Golf, Pargo)       0.52      0.85      0.65        13
#                                                 Other Transport - Stroller       0.33      1.00      0.50         2
#                                        Other Transport - Stroller - Disney       1.00      1.00      1.00         3
#                                   Other Transport - Stroller - Third Party       0.00      0.00      0.00         2
#                                                   Other Transport - Walker       0.00      0.00      0.00         1
#                             Other Transport - Wheelchair (Manual) - Disney       0.00      0.00      0.00         1
#                        Other Transport - Wheelchair (Manual) - Third Party       0.00      0.00      0.00         1
#                                                       Permanent Structures       0.07      0.25      0.11         4
#                                                Permanent Structures - Gate       0.64      0.88      0.74         8
#                              Permanent Structures - Handrail/Railing/Fence       0.67      0.33      0.44         6
#                                      Permanent Structures - Pole/Post/Pipe       0.25      0.20      0.22        10
#                                                                     Person       0.00      0.00      0.00         1
#                                                     Person - Another Guest       0.62      0.51      0.56        35
#                                                  Person - Cast/Crew Member       0.38      0.15      0.21        20
#                                      Person - Cast/Crew Member - Character       0.00      0.00      0.00         2
#                                                              Person - Self       0.60      0.08      0.14       150
#                                          Protein Spill/Other Bodily Fluids       0.14      0.50      0.22         2
#                                            Recreation/Relaxation Apparatus       0.00      0.00      0.00         1
#                        Recreation/Relaxation Apparatus - Fitness Equipment       0.00      0.00      0.00         1
#                            Recreation/Relaxation Apparatus - Hammock/Swing       0.00      0.00      0.00         1
#                             Recreation/Relaxation Apparatus - Pool Surface       0.45      1.00      0.62         5
#                         Recreation/Relaxation Apparatus - Sports Equipment       0.00      0.00      0.00         2
#                                                             Stage/Platform       0.19      0.50      0.28        10
#                                      Toxic/Flammable/Chemicals - Chemicals       0.78      0.58      0.67        36
#                       Toxic/Flammable/Chemicals - Pyrotechnics (fireworks)       1.00      1.00      1.00         1
#                                                                    Unknown       0.33      0.50      0.40         6
#                                                            Walking Surface       0.50      0.06      0.11        49
#                                    Walking Surface - Conveyance - Elevator       0.38      0.75      0.50         4
#                                                   Walking Surface - Indoor       0.67      0.32      0.43        62
#                                  Walking Surface - Indoor - Carpet/Mat/Rug       0.29      0.62      0.40         8
#                                      Walking Surface - Indoor - Stair/Step       0.59      0.68      0.63        47
#                                                  Walking Surface - Outdoor       0.44      0.12      0.19        67
#                                         Walking Surface - Outdoor - Bridge       1.00      1.00      1.00         1
#                                 Walking Surface - Outdoor - Carpet/Mat/Rug       0.00      0.00      0.00         1
#                                           Walking Surface - Outdoor - Curb       0.67      0.78      0.72        18
#                              Walking Surface - Outdoor - Ditch/Trench/Hole       0.10      0.50      0.17         2
#                                           Walking Surface - Outdoor - Dock       0.14      0.50      0.22         2
#                                    Walking Surface - Outdoor - Grate/Drain       0.12      0.50      0.20         4
#                                   Walking Surface - Outdoor - Parking Curb       0.07      0.67      0.12         3
#                                           Walking Surface - Outdoor - Ramp       0.50      0.75      0.60         4
#                                     Walking Surface - Outdoor - Stair/Step       0.25      0.22      0.23        23
#                                     Walking Surface - Outdoor - Track/Rail       0.60      1.00      0.75         3
#                                                               Wall/Ceiling       0.09      0.25      0.13         4
#                                                              Water Vehicle       0.17      0.33      0.22         3
#                    Water Vehicle - Launch Transport Boats (Not Ferry Boat)       0.00      0.00      0.00         1
#                                                  Water Vehicle - Raft/Mats       0.45      1.00      0.62         5
#                                                             Weapon - Knife       0.33      0.33      0.33         3
#
#                                                                  micro avg       0.41      0.38      0.39      1638
#                                                                  macro avg       0.31      0.43      0.32      1638
#                                                               weighted avg       0.45      0.38      0.36      1638
# C:\Users\gduln001\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\gduln001\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\gduln001\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Step 3.1: Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(
    X_tfidf, example_data['Source of Incident Desc_Encoded'], test_size=0.2, random_state=42
)

# Step 3.2: Initialize Logistic Regression with Class Weights
logistic_model = LogisticRegression(class_weight='balanced', random_state=42)

# Step 3.3: Train the Model
logistic_model.fit(X_train, y_train)

# Step 3.4: Evaluate Performance
from sklearn.metrics import classification_report

y_pred = logistic_model.predict(X_test)
report = classification_report(y_test, y_pred, target_names=label_encoders['Source of Incident Desc'].classes_)

print(report)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 16
#      13 from sklearn.metrics import classification_report
#      15 y_pred = logistic_model.predict(X_test)
# ---> 16 report = classification_report(y_test, y_pred, target_names=label_encoders['Source of Incident Desc'].classes_)
#      18 print(report)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:2648, in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2642         warnings.warn(
#    2643             "labels size, {0}, does not match size of target_names, {1}".format(
#    2644                 len(labels), len(target_names)
#    2645             )
#    2646         )
#    2647     else:
# -> 2648         raise ValueError(
#    2649             "Number of classes, {0}, does not match size of "
#    2650             "target_names, {1}. Try specifying the labels "
#    2651             "parameter".format(len(labels), len(target_names))
#    2652         )
#    2653 if target_names is None:
#    2654     target_names = ["%s" % l for l in labels]
#
# ValueError: Number of classes, 155, does not match size of target_names, 176. Try specifying the labels parameter

# %%
#################################################################################

# %%
# Initialize tokenizer and model
tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
model = AutoModel.from_pretrained('bert-base-uncased')

# Function to process a batch of text data and get embeddings
def get_bert_embeddings(text_batch):
    """
    Tokenize the input text and generate embeddings using BERT.
    Args:
        text_batch: A list of strings (text samples).
    Returns:
        numpy.ndarray: Array of embeddings for each text sample.
    """
    inputs = tokenizer(
        text_batch,
        return_tensors="pt",
        padding=True,         # Pad sentences to the same length
        truncation=True,      # Truncate sentences longer than max_length
        max_length=512        # Max token length for BERT
    )
    with torch.no_grad():  # Turn off gradients for inference
        outputs = model(**inputs)
    # Extract [CLS] token embeddings (first token in BERT output)
    return outputs.last_hidden_state[:, 0, :].numpy()

# Process embeddings in batches
batch_size = 4  # Adjust batch size based on your data and memory
embeddings = []

for i in range(0, len(df), batch_size):
    batch_texts = df['Combined_Text'][i:i + batch_size].tolist()
    batch_embeddings = get_bert_embeddings(batch_texts)
    embeddings.extend(batch_embeddings)

# Add embeddings as a new column to the DataFrame
df['BERT_Embedding'] = embeddings

# Output DataFrame with embeddings
print(df[['Combined_Text', 'BERT_Embedding']].head())

# %%
print(df['BERT_Embedding'].iloc[0].shape)  # Should output (768,) for BERT-base
print(df[['Combined_Text', 'BERT_Embedding']])

# %%
print(df['BERT_Embedding'].head())

# %%
# Encode the target labels
label_encoder = LabelEncoder()
df['Source_Encoded'] = label_encoder.fit_transform(df['Source of Incident Desc'])

# %%
label_map = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
print("Label Mapping:", label_map)

# %%
class_counts = df['Source of Incident Desc'].value_counts()

# %%
print("Class Distribution:")
print(class_counts)

# Plot the class distribution
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
class_counts.plot(kind='bar')
plt.title("Class Distribution of 'Source of Incident'")
plt.xlabel("Class")
plt.ylabel("Frequency")
plt.xticks(rotation=90)
plt.show()

# %%
data

# %%
#df.to_excel('J:/Data/RMSA Analysis/0 - Team Working Files/10 - Nick/WCMLDataset.xlsx', index=False)
