# %%
import pandas as pd

# %%
data = pd.read_csv('TestCCPAData.csv')

# %%
data
# Out:
#         ID  REQUEST ID  FIRST NAME    LAST NAME                         EMAIL  \
# 0    15200         NaN         NaN          NaN                           NaN
# 1    15199  SN7HVN8KL3       Molly     Shahvari           mmmc525@outlook.com
# 2    15198  KX66BXZRBR  Candelaria        Avila        candeangeljr@gmail.com
# 3    15197  JSBBVZT97P      Clovis      Capuzzo           cclovis49@yahoo.com
# 4    15196  PT7KT7TJ53       becky        evans      beckylharper33@gmail.com
# ..     ...         ...         ...          ...                           ...
# 313  14887  AWQ634TG3Y    Loretta   Lesperance         ltlesperance@gmail.com
# 314  14886  4Q3TRKNARK       Angel     Principe          petardoagp@gmail.com
# 315  14885  T7BMSGCFJS    Samantha    Denenberg  denenberg.samantha@gmail.com
# 316  14884  R7S6PS4NM7       Kelly        Soich       wx_navigator@icloud.com
# 317  14883  K7FTCYCP7J       alana           yi    alana.yi1978@sbcglobal.net
#
# ...
