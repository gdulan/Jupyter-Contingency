# %%
import pandas as pd

# %%
# 100 synthetic sprinkler head incidents
incident_descriptions = [
    "While walking towards the towel return station near the garden, the guest stubbed her left big toe on a sprinkler head that was slightly raised above the grass.",
    "As the guest made her way to the outdoor seating area, her foot caught on a sprinkler nozzle protruding from the lawn, causing her to stumble and twist her ankle.",
    "He was heading back to his lounge chair by the pool when he hit his forefoot against a sprinkler head hidden beneath low foliage, resulting in a minor toe sprain.",
    "The guest reported tripping over a sprinkler head installed along the walkway’s edge, scraping her knee and palm as she tried to catch herself.",
    "On the path to the locker rooms, a visitor struck her toe on an exposed sprinkler, causing her to lose balance and bruise her shin upon falling.",
    "Moving quickly to catch up with her friends, the guest clipped her sandal on a sprinkler head jutting from the grass, leading to a small cut on her toe.",
    "He stepped off the main walkway onto a grassy patch and caught his foot on a sprinkler that wasn’t fully retracted, resulting in a stubbed toe and slight limp.",
    "A guest heading to the restroom area near the cabanas stubbed her toe on a sprinkler installed along the pathway, experiencing minor swelling in her foot.",
    "While cutting through a landscaped shortcut, the guest tripped over a raised sprinkler, tumbling forward and bruising her left knee.",
    "En route to the changing rooms, she didn’t notice the sprinkler head protruding from the ground and caught it with her sandal, causing her to twist her ankle.",
    "Walking barefoot back from the pool, the guest’s right toe hit a sprinkler head, leading her to stumble and scrape both her palms on the concrete.",
    "On his way to the outdoor showers, the guest brushed his foot against a poorly recessed sprinkler, leading to a small laceration on his toe.",
    "She was hurrying towards the rest area when her flip-flop caught on a sprinkler head, causing her to trip and bruise her forearm on the fall.",
    "A visitor claims that while strolling near the garden lights, she inadvertently hit her foot on a sprinkler protrusion, leaving her with a swollen toe.",
    "As he headed toward the picnic section, the guest’s toe collided with a sprinkler spout, making him stumble and strain a muscle in his calf.",
    "The guest complained that the sprinkler head along the paved walkway wasn’t flush with the surface, resulting in her tripping and scraping her knee.",
    "Walking to the snack bar barefoot, he caught his big toe on a sprinkler that stuck out slightly from the grass, causing a painful toenail crack.",
    "She took a shortcut behind some shrubs and caught her ankle on a sprinkler head, falling onto her side and bruising her hip.",
    "The guest indicated that while approaching the restrooms, she struck her toe against a sprinkler head, twisting her ankle and causing mild pain.",
    "He attempted to step over a low hedge, not realizing a sprinkler was there, and ended up tripping and scraping his elbow on the ground.",
    "As she made her way back to the loungers, the guest stepped on a sprinkler nozzle, bending her toe and causing a minor sprain.",
    "The guest reports that he tripped over a sprinkler head near the children’s play area, injuring his knee as he fell onto the walkway.",
    "While walking along a dimly lit path, she kicked a sprinkler head that wasn’t fully retracted, resulting in a bruised toe and mild discomfort.",
    "On the way to the fitness center, he stubbed his toe on a sprinkler that was slightly raised above the turf, causing a small abrasion.",
    "She claims that the sprinkler head near the roses protruded enough to snag her shoe, causing her to fall forward and scrape her chin.",
    "Hurrying to the nearest restroom, the guest’s foot caught on a sprinkler along the pathway’s edge, leading to a twisted ankle.",
    "While heading to the lobby area, a visitor stubbed her toe on an elevated sprinkler head, leaving her limping slightly.",
    "The guest said he tripped over a sprinkler nestled in the grass while returning from the pool bar, resulting in a minor bruise on his shin.",
    "As she crossed a patch of lawn to reach a restroom, her toe hit a sprinkler, causing her to lose balance and land on her left wrist.",
    "He reported that the sprinkler head near the patio was not flush, causing him to catch his foot and scuff his knee upon falling.",
    "Walking barefoot after leaving the pool, she hit her toe on a sprinkler head, breaking the skin and causing minor bleeding.",
    "The guest was heading back from the beach area and encountered a raised sprinkler, stumbling and scraping both knees on the pavement.",
    "While making her way to an outdoor shower, she caught her sandal on a sprinkler and twisted her ankle, experiencing immediate pain.",
    "He stepped off the main path onto a grassy edge, catching his toe on a sprinkler nozzle and falling forward onto his hands.",
    "The guest tripped over a sprinkler near the dining terrace, scraping her elbow as she attempted to break her fall.",
    "On his route to the changing area, he stubbed his toe on a sprinkler protruding from the lawn, causing mild swelling.",
    "She tried to take a shortcut through a landscaped section, only to trip on a sprinkler and fall, bruising her shoulder.",
    "As he returned from the restroom, his flip-flop caught on a sprinkler head, nearly causing him to fall and resulting in a sore toe.",
    "The guest mentioned the sprinkler head near the pathway was angled upward, causing her to stub her big toe and stumble.",
    "Walking towards the lockers, he hit his toe on a slightly raised sprinkler, chipping a portion of his toenail.",
    "She explained that while heading back to her lounger, she did not see the sprinkler head and tripped, landing on her right knee.",
    "On the way to the restroom, the guest snagged her foot on a sprinkler’s metal edge, leading to a small cut on her toe.",
    "He reported walking along a grassy strip when his toe hit a sprinkler head, causing him to fall and bruise his forearm.",
    "Returning from the pool, she caught her foot on a sprinkler and stumbled, skinning her left palm on the concrete.",
    "While heading to the snack shack, the guest tripped over a sprinkler that protruded slightly, spraining his ankle.",
    "She stepped off the main path onto a grassy patch and hit a sprinkler head, causing her to twist her ankle and scrape her shin.",
    "As he approached the changing area, he caught his foot on a sprinkler, losing balance and straining his right wrist.",
    "The guest complained about a sprinkler head sticking out of the lawn near the bathhouse, which caused her to stub her toe hard.",
    "While making her way back to her seat, she accidentally kicked a sprinkler nozzle, leading to a bruised big toe.",
    "He ventured off the designated walkway and tripped on a sprinkler hidden in the grass, scraping his knee and palm.",
    "Heading for the restrooms, the guest snagged her foot on a sprinkler head and stumbled, getting a minor abrasion on her right knee.",
    "While crossing a small lawn area, she hit a sprinkler protrusion, causing her to fall forward and bruise her elbow.",
    "He tried to shortcut through the landscaping, caught his toe on a sprinkler, and ended up with a skinned knee.",
    "Walking to the showers, the guest clipped her toe on a sprinkler head, causing immediate discomfort and slight swelling.",
    "The visitor reported stepping onto what he thought was flat grass, only to kick a sprinkler and twist his ankle.",
    "While heading toward the rest area, she tripped on a slightly raised sprinkler head, spraining her left foot.",
    "The guest noted that the sprinkler head near the restrooms was exposed, resulting in a stubbed toe and a scraped hand as she fell.",
    "He caught his sandal on a sprinkler while walking barefoot, causing him to trip and bruise his shin upon landing.",
    "As she headed to the changing rooms, her foot caught on a sprinkler nozzle, causing her to stumble and scrape her palms.",
    "The guest tripped over a sprinkler head hidden near the bushes, resulting in a minor cut on her toe and a bruised hip.",
    "He was walking quickly to the restroom and hit a sprinkler, stumbling and spraining his ankle.",
    "Barefoot and hurrying, she struck her toe against a sprinkler, causing a painful toenail crack and minor bleeding.",
    "While going toward the pool showers, the guest did not see the sprinkler head and tripped, scraping her left elbow.",
    "He claims he stepped on a sprinkler sticking out from the lawn, resulting in a sore toe and slight limp.",
    "On the path to the changing stations, she clipped her foot on a sprinkler head, twisting her ankle slightly.",
    "The guest reported that a sprinkler head near the lounge area caused her to trip, leading to a scraped knee.",
    "He stepped off the main path and caught his toe on a sprinkler nozzle, resulting in a small cut and bruising.",
    "As she walked barefoot back from the pool, her toe caught a sprinkler head, causing her to fall and graze her forearm.",
    "He didn’t notice the sprinkler head near the walkway and ended up stubbing his big toe hard, leaving it sore.",
    "She stumbled over a raised sprinkler while heading to the locker area, scraping her palms and knee upon falling.",
    "Walking near the restroom signs, the guest’s foot caught on a sprinkler, leading to a twisted ankle and mild swelling.",
    "He was making his way to the refreshment stand when he tripped over a sprinkler, chipping a portion of his toenail.",
    "She hit her toe on a sprinkler head that stuck out of the ground, causing her to limp and complain of toe pain.",
    "While approaching the rest area, he stumbled over a sprinkler nozzle, scraping his knee as he tried to regain balance.",
    "The guest mentioned catching her foot on a poorly recessed sprinkler by the walkway, leading to a bruised shin.",
    "She took a shortcut through the landscaping and ended up tripping on a sprinkler, resulting in a skinned elbow.",
    "He noticed too late that a sprinkler protruded from the lawn, stubbing his toe and nearly falling.",
    "As she headed to the showers, her foot hooked onto a sprinkler head, causing her to stumble and bruise her hip.",
    "He stepped off the main path to avoid a puddle and hit his toe on a sprinkler, causing immediate toe pain.",
    "While walking to the restrooms, she caught her sandal on a sprinkler nozzle, twisting her ankle slightly.",
    "He tried to cut across the grass and snagged his toe on a sprinkler, ending up with a scraped knee.",
    "Moving towards the locker area, the guest stubbed her toe on a sprinkler head, resulting in minor bleeding.",
    "He stumbled over a raised sprinkler while heading to the restroom and bruised his right forearm.",
    "As she returned from the showers, her foot struck a sprinkler head, causing her to fall and scrape her left palm.",
    "He caught his toe on a sprinkler hidden in the shrubbery, twisting his ankle and wincing in pain.",
    "She hit a sprinkler nozzle with her heel, tripping and scuffing her right knee on the pavement.",
    "The guest reported that a sprinkler along the path caused him to stub his toe and limp for the rest of the day.",
    "On her way to the changing area, she tripped on a protruding sprinkler, bruising her elbow upon falling.",
    "He stepped into the grass to avoid a crowd and hit his toe on a sprinkler, leaving a small cut on his toe.",
    "While walking barefoot near the pool area, the guest’s big toe collided with a sprinkler head, causing swelling.",
    "She stumbled over a sprinkler that stuck out slightly from the lawn, resulting in a scraped hand and sore toe.",
    "He tried to step around a puddle and ended up kicking a sprinkler nozzle, straining his right ankle.",
    "The guest said the sprinkler near the path was not fully retracted, causing her to trip and bruise her shin.",
    "As she approached the restroom, her foot caught on a sprinkler head, leading to a minor fall and a scraped elbow.",
    "He stubbed his toe on a sprinkler hidden in the grass, causing him to falter and scuff his knee.",
    "She inadvertently kicked a sprinkler nozzle while heading to the lockers, twisting her ankle slightly.",
    "The guest explains he tripped on a raised sprinkler and scraped his palm and forearm breaking his fall.",
    "While moving towards the snack area, she caught her foot on a sprinkler, bruising her left knee on impact.",
    "He took a shortcut along the grass and ended up kicking a sprinkler head, resulting in a stubbed and painful toe.",
    "She walked barefoot to the showers and struck her toe on a sprinkler protrusion, causing minor bleeding.",
    "He stumbled over a sprinkler while heading toward the bathhouse, scraping both palms as he tried to catch himself.",
    "On her route to the changing station, she kicked a sprinkler head and twisted her ankle, resulting in mild swelling.",
    "He clipped his toe on a sprinkler barely visible above the grass, falling forward and bruising his elbow.",
    "As she hurried to the restroom, her flip-flop caught on a sprinkler, causing her to stumble and scratch her knee.",
    "He stepped off the main sidewalk onto the lawn, hitting his toe on a sprinkler and yelping in pain.",
    "She tripped on a sprinkler nozzle while cutting through bushes, scraping her palms, right knee, and right arm.",
    "On her way to the changing rooms, the guest accidentally caught her toe on a misting sprinkler protruding too far, breaking her pinkie toe.",
    "She decided to cut through the bushes, tripped on a sprinkler, and fell, scratching both palms, her right knee, right arm, and experiencing pain in her right wrist."
]

# Create a dataframe
df = pd.DataFrame({'Incident Description': incident_descriptions})

# Save to Excel
df.to_excel('J:/Data/RMSA Analysis/0 - Team Working Files/10 - Nick/Sprinkler.xlsx', index=False)
print("Excel file 'synthetic_sprinkler_incidents.xlsx' created with 100 samples.")
# Out:
# Excel file 'synthetic_sprinkler_incidents.xlsx' created with 100 samples.
