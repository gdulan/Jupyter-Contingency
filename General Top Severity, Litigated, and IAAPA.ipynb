# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('Top Severity_Litigated_IAAPA - Analysis.xlsx')
# Out:
#         Setid Client ID-Claim Date of Incident/Loss Fiscal Year Fiscal Month  \
# 0         1.0             WDW            2020-10-01        FY20       12_Sep
# 1         1.0             WDW            2020-10-01        FY20       12_Sep
# 2         1.0             WDW            2020-10-01        FY20       12_Sep
# 3         1.0             WDW            2020-10-01        FY20       12_Sep
# 4         1.0             WDW            2020-10-01        FY20       12_Sep
# ...       ...             ...                   ...         ...          ...
# 102546    1.0             WDW            2023-11-12        FY24        2_Nov
# 102547    1.0             WDW            2023-11-12        FY24        2_Nov
# 102548    1.0             WDW            2023-11-13        FY24        2_Nov
# 102549    NaN             NaN                   NaT         NaN          NaN
# 102550    NaN             NaN                   NaT         NaN          NaN
#
#         Time of Incident/Loss Incident to Claim Date Occurrence Number  \
# 0                       915.0                    NaT    WDWG2020636646
# 1                       930.0                    NaT    WDWG2020636644
# 2                       945.0                    NaT    WDWG2020636688
# 3                      1120.0                    NaT    WDWG2020636689
# 4                      1220.0                    NaT    WDWG2020636690
# ...                       ...                    ...               ...
# 102546                    NaN                    NaT    WDWG2023729089
# 102547                    NaN                    NaT    WDWG2023729126
# 102548                  949.0                    NaT               NaN
# 102549                    NaN                    NaT               NaN
# 102550                    NaN                    NaT               NaN
#
#           Claim Number Age at Date of Incident  ... Attorney Represented  \
# 0       WDWG2020636646                       3  ...                  NaN
# 1       WDWG2020636644                       0  ...                  NaN
# 2       WDWG2020636688                     NaN  ...                  NaN
# 3       WDWG2020636689                     NaN  ...                  NaN
# 4       WDWG2020636690                       6  ...                  NaN
# ...                ...                     ...  ...                  ...
# 102546  WDWG2023729089                     NaN  ...                  NaN
# 102547  WDWG2023729126                       7  ...                  NaN
# 102548  WDWG2023729143                      19  ...                  NaN
# 102549             NaN                     NaN  ...                  NaN
# 102550           97820                     NaN  ...                  NaN
#
#         Attorney Represented Desc Service Co. TPA Code/Carrier Code  \
# 0                             NaN                              SELF
# 1                             NaN                              SELF
# 2                             NaN                              SELF
# 3                             NaN                              SELF
# 4                             NaN                              SELF
# ...                           ...                               ...
# 102546                        NaN                              SELF
# 102547                        NaN                              FIRE
# 102548                        NaN                              SELF
# 102549                        NaN                               NaN
# 102550                        NaN                               NaN
#
#        Service Co. TPA Code/Carrier Code Name DVC/Fireman's Fund Flag  \
# 0                           Self-administered                     NaN
# 1                           Self-administered                     NaN
# 2                           Self-administered                     NaN
# 3                           Self-administered                     NaN
# 4                           Self-administered                     NaN
# ...                                       ...                     ...
# 102546                      Self-administered                     NaN
# 102547                     DVC/Fireman's Fund                     1.0
# 102548                      Self-administered                     NaN
# 102549                                    NaN                     NaN
# 102550                                    NaN                     NaN
#
#        DVC/Fireman's Fund Flag Desc Disney Claim Total Incurred  \
# 0                               NaN                         NaN
# 1                               NaN                         NaN
# 2                               NaN                         NaN
# 3                               NaN                         NaN
# 4                               NaN                         NaN
# ...                             ...                         ...
# 102546                          NaN                         NaN
# 102547                  Record Only                         NaN
# 102548                          NaN                         NaN
# 102549                          NaN                         NaN
# 102550                          NaN                         NaN
#
#        Disney Claim Total Paid  Disney Claim Total Reserve  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
# ...                        ...                         ...
# 102546                     NaN                         NaN
# 102547                     NaN                         NaN
# 102548                     NaN                         NaN
# 102549                     NaN                         NaN
# 102550                     NaN                         NaN
#
#                                         GPoint
# 0       28.418116527170188, -81.57954785648487
# 1                                          NaN
# 2                                          NaN
# 3        28.37622025113795, -81.54942184129224
# 4        28.357480800876115, -81.5905798598985
# ...                                        ...
# 102546   28.42035291388911, -81.58185844712867
# 102547                                     NaN
# 102548  28.420251375387753, -81.57709714472911
# 102549                                     NaN
# 102550                                     NaN
#
# [102551 rows x 68 columns]

# %%
pd.set_option('display.max_columns', None)
# Out:
#         Setid Client ID-Claim Date of Incident/Loss Fiscal Year Fiscal Month  \
# 0         1.0             WDW            2020-10-01        FY20       12_Sep
# 1         1.0             WDW            2020-10-01        FY20       12_Sep
# 2         1.0             WDW            2020-10-01        FY20       12_Sep
# 3         1.0             WDW            2020-10-01        FY20       12_Sep
# 4         1.0             WDW            2020-10-01        FY20       12_Sep
# ...       ...             ...                   ...         ...          ...
# 102546    1.0             WDW            2023-11-12        FY24        2_Nov
# 102547    1.0             WDW            2023-11-12        FY24        2_Nov
# 102548    1.0             WDW            2023-11-13        FY24        2_Nov
# 102549    NaN             NaN                   NaT         NaN          NaN
# 102550    NaN             NaN                   NaT         NaN          NaN
#
#         Time of Incident/Loss Incident to Claim Date Occurrence Number  \
# 0                       915.0                    NaT    WDWG2020636646
# 1                       930.0                    NaT    WDWG2020636644
# 2                       945.0                    NaT    WDWG2020636688
# 3                      1120.0                    NaT    WDWG2020636689
# 4                      1220.0                    NaT    WDWG2020636690
# ...                       ...                    ...               ...
# 102546                    NaN                    NaT    WDWG2023729089
# 102547                    NaN                    NaT    WDWG2023729126
# 102548                  949.0                    NaT               NaN
# 102549                    NaN                    NaT               NaN
# 102550                    NaN                    NaT               NaN
#
#           Claim Number Age at Date of Incident Adjuster Name Name  \
# 0       WDWG2020636646                       3         GC, Team 1
# 1       WDWG2020636644                       0         GC, Team 1
# 2       WDWG2020636688                     NaN         GC, Team 1
# 3       WDWG2020636689                     NaN         GC, Team 3
# 4       WDWG2020636690                       6         GC, Team 2
# ...                ...                     ...                ...
# 102546  WDWG2023729089                     NaN         GC, Team 3
# 102547  WDWG2023729126                       7         GC, Team 1
# 102548  WDWG2023729143                      19         GC, Team 1
# 102549             NaN                     NaN                NaN
# 102550           97820                     NaN                NaN
#
#         Major Coverage Major Coverage Desc Coverage  \
# 0                 20.0   General Liability       22
# 1                 20.0   General Liability       22
# 2                 20.0   General Liability       22
# 3                 20.0   General Liability       22
# 4                 20.0   General Liability       22
# ...                ...                 ...      ...
# 102546            20.0   General Liability       22
# 102547            20.0   General Liability       22
# 102548            20.0   General Liability       22
# 102549             NaN                 NaN      NaN
# 102550             NaN                 NaN      NaN
#
#                             Coverage Desc Claim Status Claim Status Code  \
# 0       General Liability - Bodily Injury     INCIDENT                 I
# 1       General Liability - Bodily Injury     INCIDENT                 I
# 2       General Liability - Bodily Injury     INCIDENT                 I
# 3       General Liability - Bodily Injury     INCIDENT                 I
# 4       General Liability - Bodily Injury     INCIDENT                 I
# ...                                   ...          ...               ...
# 102546  General Liability - Bodily Injury     INCIDENT                 I
# 102547  General Liability - Bodily Injury     INCIDENT                 I
# 102548  General Liability - Bodily Injury     INCIDENT                 I
# 102549                                NaN          NaN               NaN
# 102550                                NaN          NaN               NaN
#
#        Claim or Incident?  Business Area Desc  \
# 0                Incident                 NaN
# 1                Incident                 NaN
# 2                Incident                 NaN
# 3                Incident                 NaN
# 4                Incident                 NaN
# ...                   ...                 ...
# 102546           Incident                 NaN
# 102547           Incident                 NaN
# 102548           Incident                 NaN
# 102549                NaN                 NaN
# 102550                NaN                 NaN
#
#                         Personnel Area Desc  \
# 0            2092 - MAGIC KINGDOM 1029 - FL
# 1               0538 - CARIBBEAN BEACH - FL
# 2         0657 - WDW ADMIN AND SUPPORT - FL
# 3                         0569 - EPCOT - FL
# 4           2227 - ANIMAL KINGDOM 1029 - FL
# ...                                     ...
# 102546       2092 - MAGIC KINGDOM 1029 - FL
# 102547  0567 - DVC-DISNEY OLD KEY WEST - FL
# 102548       2092 - MAGIC KINGDOM 1029 - FL
# 102549                                  NaN
# 102550                                  NaN
#
#                              Division Desc               Building Desc  \
# 0                       Magic Kingdom Park                Tomorrowland
# 1          Disney's Caribbean Beach Resort         Jamaica Guest Rooms
# 2                   Other On Property Area                         NaN
# 3                                    Epcot       Main Entrance - Epcot
# 4       Disney's Animal Kingdom Theme Park                         NaN
# ...                                    ...                         ...
# 102546                  Magic Kingdom Park                 Fantasyland
# 102547        Disney's Old Key West Resort  Guest Rooms - Old Key West
# 102548                  Magic Kingdom Park                Tomorrowland
# 102549                                 NaN                         NaN
# 102550                                 NaN                         NaN
#
#                            Department Desc Location At Level 5 Desc  \
# 0       Buzz Lightyear's Space Ranger Spin                      NaN
# 1                                      NaN                      NaN
# 2                                      NaN                      NaN
# 3                                      NaN                      NaN
# 4                                      NaN                      NaN
# ...                                    ...                      ...
# 102546                    Castle Courtyard       Peter Pan's Flight
# 102547                                 NaN                      NaN
# 102548                 TRON Lightcycle Run                      NaN
# 102549                                 NaN                      NaN
# 102550                                 NaN                      NaN
#
#                         Location Code Desc   Line of Business Desc  \
# 0       Buzz Lightyear's Space Ranger Spin              Attraction
# 1                      Jamaica Guest Rooms             Guest Rooms
# 2                   Other On Property Area  Other On Property Area
# 3                    Main Entrance - Epcot             Themed Area
# 4       Disney's Animal Kingdom Theme Park            Park Overall
# ...                                    ...                     ...
# 102546                  Peter Pan's Flight              Attraction
# 102547          Guest Rooms - Old Key West             Guest Rooms
# 102548                 TRON Lightcycle Run              Attraction
# 102549                                 NaN                     NaN
# 102550                                 NaN                     NaN
#
#        Sub Location  Sub Location Desc  \
# 0             WALKO    Walkway Outside
# 1             RMGEN  In Room - General
# 2              OTHR     Other Location
# 3             WALKS           Walkways
# 4             WALKS           Walkways
# ...             ...                ...
# 102546       UNLOAD             Unload
# 102547      PLGUEST      Guest Parking
# 102548        QLINE         Queue Line
# 102549          NaN                NaN
# 102550          NaN                NaN
#
#                                      Incident Description  \
# 0       Sarah stated that her daughter, Aubrey, fell w...
# 1       guest is claiming ADA discrimination based on ...
# 2       "I messed up my right shoulder yesterday and m...
# 3       Guest ambulated into GFA stating her granddaug...
# 4       As per mom, "child was walking and tripped and...
# ...                                                   ...
# 102546  Guest was stepping out of Boat at Peter Pan's ...
# 102547  Guest father reported that son, Ashton, was ha...
# 102548  Guest jumped over the queue railing over at TR...
# 102549                                                NaN
# 102550                                                NaN
#
#                                        Injury Description  \
# 0        Grandma ran over the child with her personal ECV
# 1       guest has stated that she will be in contact w...
# 2       right shoulder injury.  tenderness to right sh...
# 3                                               See GFAAR
# 4                                           trip and fall
# ...                                                   ...
# 102546  Guests knee was knocked when boats stopped une...
# 102547  Guest father reported guest was having trouble...
# 102548  Swelling, throbbing and pain to the right foot...
# 102549                                                NaN
# 102550                                                NaN
#
#                                  Cast Member Observations  \
# 0       There were no noticeable injuries that I could...
# 1       Duty spoke with guest evening of 9/30.  Conver...
# 2       guest came in with complaints of right shoulde...
# 3                                               See GFAAR
# 4                                          Refer to GFAAR
# ...                                                   ...
# 102546                                                NaN
# 102547                                                NaN
# 102548  I received a call from one of my Cast Members ...
# 102549                                                NaN
# 102550                                                NaN
#
#        Physical Characteristics Desc  Other Description  \
# 0            Body Type - Small Child                NaN
# 1                            Unknown                NaN
# 2            Body Type - Large Adult                NaN
# 3                                NaN                NaN
# 4                                NaN                NaN
# ...                              ...                ...
# 102546       Body Type - Small Adult                NaN
# 102547                           NaN                NaN
# 102548       Body Type - Large Adult                NaN
# 102549                           NaN                NaN
# 102550                           NaN                NaN
#
#              Event of Incident Desc  \
# 0                  Struck/Struck By
# 1               Guest Inconvenience
# 2                       Body Motion
# 3                 Slip/Trip/Misstep
# 4         Slip/Trip/Misstep  - Trip
# ...                             ...
# 102546        On Ride - Sudden Stop
# 102547            Fatigue / Illness
# 102548  Fall/Jump out/off of - Jump
# 102549                          NaN
# 102550                          NaN
#
#                                   Source of Incident Desc  \
# 0                     Other Transport - ECV - Third Party
# 1                            Food/Drink and Related Items
# 2                                           Person - Self
# 3                               Walking Surface - Outdoor
# 4                               Walking Surface - Outdoor
# ...                                                   ...
# 102546  Attraction Related - Park Vehicle - Attraction...
# 102547                                      Person - Self
# 102548      Permanent Structures - Handrail/Railing/Fence
# 102549                                                NaN
# 102550                                                NaN
#
#        Event of Injury Desc  \
# 0          Struck/Struck By
# 1        No Injury Reported
# 2               Body Motion
# 3          Struck/Struck By
# 4          Struck/Struck By
# ...                     ...
# 102546     Struck/Struck By
# 102547    Fatigue / Illness
# 102548     Struck/Struck By
# 102549                  NaN
# 102550                  NaN
#
#                                     Source of Injury Desc  EDI Body Part Desc  \
# 0                               Walking Surface - Outdoor                 NaN
# 1       No Injury Reported (Only use for Source of Inj...                 NaN
# 2                                           Person - Self                 NaN
# 3                               Walking Surface - Outdoor                 NaN
# 4                               Walking Surface - Outdoor                 NaN
# ...                                                   ...                 ...
# 102546                   Attraction Related - Moving Belt                 NaN
# 102547                                      Person - Self                 NaN
# 102548                          Walking Surface - Outdoor                 NaN
# 102549                                                NaN                 NaN
# 102550                                                NaN                 NaN
#
#           Body Part 1 Desc Body Part 1 Group Body Part 2 Desc  \
# 0                    Ankle         Legs/Feet             Knee
# 1       No Injury Reported               NaN              NaN
# 2                 Shoulder          Arm/Hand              NaN
# 3                     Knee         Legs/Feet              NaN
# 4                    Elbow          Arm/Hand              NaN
# ...                    ...               ...              ...
# 102546                Knee         Legs/Feet     General Body
# 102547               Chest             Torso              NaN
# 102548               Ankle         Legs/Feet            Ankle
# 102549                 NaN               NaN              NaN
# 102550                 NaN               NaN              NaN
#
#        Body Part 2 Group Body Part 3 Desc Body Part 3 Group Body Part 4 Desc  \
# 0              Legs/Feet             Hand          Arm/Hand              NaN
# 1                    NaN              NaN               NaN              NaN
# 2                    NaN              NaN               NaN              NaN
# 3                    NaN              NaN               NaN              NaN
# 4                    NaN              NaN               NaN              NaN
# ...                  ...              ...               ...              ...
# 102546           General              NaN               NaN              NaN
# 102547               NaN              NaN               NaN              NaN
# 102548         Legs/Feet             Foot         Legs/Feet             Foot
# 102549               NaN              NaN               NaN              NaN
# 102550               NaN              NaN               NaN              NaN
#
#        Body Part 4 Group Body Part 5 Desc Body Part 5 Group  \
# 0                    NaN              NaN               NaN
# 1                    NaN              NaN               NaN
# 2                    NaN              NaN               NaN
# 3                    NaN              NaN               NaN
# 4                    NaN              NaN               NaN
# ...                  ...              ...               ...
# 102546               NaN              NaN               NaN
# 102547               NaN              NaN               NaN
# 102548         Legs/Feet              NaN               NaN
# 102549               NaN              NaN               NaN
# 102550               NaN              NaN               NaN
#
#        Body Part Group (Overall) Nature of Injury 1 Desc  \
# 0                       Multiple   Abrasion/Cut/Puncture
# 1                            NaN      No Injury Reported
# 2                       Arm/Hand         Pain/Discomfort
# 3                      Legs/Feet   Abrasion/Cut/Puncture
# 4                       Arm/Hand   Abrasion/Cut/Puncture
# ...                          ...                     ...
# 102546                  Multiple         Pain/Discomfort
# 102547                     Torso            Asphyxiation
# 102548                 Legs/Feet           Sprain/Strain
# 102549                       NaN                     NaN
# 102550                       NaN                     NaN
#
#        Nature of Injury 2 Desc Nature of Injury 3 Desc  \
# 0        Abrasion/Cut/Puncture   Abrasion/Cut/Puncture
# 1                          NaN                     NaN
# 2                          NaN                     NaN
# 3                          NaN                     NaN
# 4                          NaN                     NaN
# ...                        ...                     ...
# 102546        Bruise/Contusion                     NaN
# 102547                     NaN                     NaN
# 102548         Pain/Discomfort   Inflammation/Swelling
# 102549                     NaN                     NaN
# 102550                     NaN                     NaN
#
#        Nature of Injury 4 Desc Nature of Injury 5 Desc  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# 2                          NaN                     NaN
# 3                          NaN                     NaN
# 4                          NaN                     NaN
# ...                        ...                     ...
# 102546                     NaN                     NaN
# 102547                     NaN                     NaN
# 102548         Pain/Discomfort                     NaN
# 102549                     NaN                     NaN
# 102550                     NaN                     NaN
#
#        Treatment Code (IAAPA) Desc           Severity Duplicate IAAPA Desc  \
# 0                 4 First Aid Only     First Aid Only                  NaN
# 1              6 Non-Injury Report  Non-Injury Report                  NaN
# 2                 4 First Aid Only     First Aid Only                  NaN
# 3                 4 First Aid Only     First Aid Only                  NaN
# 4                 4 First Aid Only     First Aid Only                  NaN
# ...                            ...                ...                  ...
# 102546              5 No Treatment       No Treatment                  NaN
# 102547            4 First Aid Only     First Aid Only                  NaN
# 102548            4 First Aid Only     First Aid Only                  NaN
# 102549                         NaN                NaN                  NaN
# 102550                         NaN                NaN                  NaN
#
#        Litigation Desc Attorney Represented Attorney Represented Desc  \
# 0                  NaN                  NaN                       NaN
# 1                  NaN                  NaN                       NaN
# 2                  NaN                  NaN                       NaN
# 3                  NaN                  NaN                       NaN
# 4                  NaN                  NaN                       NaN
# ...                ...                  ...                       ...
# 102546             NaN                  NaN                       NaN
# 102547             NaN                  NaN                       NaN
# 102548             NaN                  NaN                       NaN
# 102549             NaN                  NaN                       NaN
# 102550             NaN                  NaN                       NaN
#
#        Service Co. TPA Code/Carrier Code  \
# 0                                   SELF
# 1                                   SELF
# 2                                   SELF
# 3                                   SELF
# 4                                   SELF
# ...                                  ...
# 102546                              SELF
# 102547                              FIRE
# 102548                              SELF
# 102549                               NaN
# 102550                               NaN
#
#        Service Co. TPA Code/Carrier Code Name  DVC/Fireman's Fund Flag  \
# 0                           Self-administered                      NaN
# 1                           Self-administered                      NaN
# 2                           Self-administered                      NaN
# 3                           Self-administered                      NaN
# 4                           Self-administered                      NaN
# ...                                       ...                      ...
# 102546                      Self-administered                      NaN
# 102547                     DVC/Fireman's Fund                      1.0
# 102548                      Self-administered                      NaN
# 102549                                    NaN                      NaN
# 102550                                    NaN                      NaN
#
#        DVC/Fireman's Fund Flag Desc  Disney Claim Total Incurred  \
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
# ...                             ...                          ...
# 102546                          NaN                          NaN
# 102547                  Record Only                          NaN
# 102548                          NaN                          NaN
# 102549                          NaN                          NaN
# 102550                          NaN                          NaN
#
#         Disney Claim Total Paid  Disney Claim Total Reserve  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ...                         ...                         ...
# 102546                      NaN                         NaN
# 102547                      NaN                         NaN
# 102548                      NaN                         NaN
# 102549                      NaN                         NaN
# 102550                      NaN                         NaN
#
#                                         GPoint
# 0       28.418116527170188, -81.57954785648487
# 1                                          NaN
# 2                                          NaN
# 3        28.37622025113795, -81.54942184129224
# 4        28.357480800876115, -81.5905798598985
# ...                                        ...
# 102546   28.42035291388911, -81.58185844712867
# 102547                                     NaN
# 102548  28.420251375387753, -81.57709714472911
# 102549                                     NaN
# 102550                                     NaN
#
# [102551 rows x 68 columns]

# %%
# Assuming your DataFrame is named Severity
def update_event_desc(value):
    if pd.notna(value) and 'Slip/Trip/Misstep' in value:
        return 'Slip/Trip/Misstep'
    return value

data['Event of Incident Desc'] = data['Event of Incident Desc'].apply(update_event_desc)

# %%
fy23data = data[data['Fiscal Year'] == 'FY23']

Severity = fy23data.groupby(['Event of Incident Desc', 'Source of Incident Desc'])[['Disney Claim Total Incurred', 'Claim Number']].agg({'Disney Claim Total Incurred': 'sum', 'Claim Number': 'nunique'}).nlargest(20, 'Disney Claim Total Incurred')
Severity.reset_index(inplace=True)
# Out:
#          Event of Incident Desc  \
# 0             Slip/Trip/Misstep
# 1             Slip/Trip/Misstep
# 2              Struck/Struck By
# 3             Slip/Trip/Misstep
# 4             Slip/Trip/Misstep
# 5         On Ride - Ride Motion
# 6             Slip/Trip/Misstep
# 7               Eating/Drinking
# 8                       Unknown
# 9             Slip/Trip/Misstep
# 10            Slip/Trip/Misstep
# 11        On Ride - Ride Motion
# 12            Slip/Trip/Misstep
# 13  Fall/Jump out/off of - Fall
# 14            Slip/Trip/Misstep
# 15            Slip/Trip/Misstep
# 16             Struck/Struck By
# 17             Struck/Struck By
# 18            Slip/Trip/Misstep
# 19            Slip/Trip/Misstep
#
#                               Source of Incident Desc  \
# 0                           Walking Surface - Outdoor
# 1                            Walking Surface - Indoor
# 2       Permanent Structures - Handrail/Railing/Fence
# 3              Walking Surface - Outdoor - Stair/Step
# 4   Attraction Related - Park Vehicle - Attraction...
# 5   Attraction Related - Park Vehicle - Attraction...
# 6                    Walking Surface - Outdoor - Curb
# 7   Food/Drink and Related Items - Food Item/Beverage
# 8                                             Unknown
# 9   Furnishings/Fixtures/Decorations - Rack/Shelf/...
# 10                         Environment - Water/Liquid
# 11                       Motor Vehicle - Bus - Disney
# 12                   Walking Surface - Outdoor - Ramp
# 13                              Other Transport - ECV
# 14              Walking Surface - Indoor - Stair/Step
# 15                           Environment - Rock/Stone
# 16                        Building/Cruise Ship - Door
# 17                             Person - Another Guest
# 18                                            Objects
# 19           Walking Surface - Outdoor - Parking Curb
#
#     Disney Claim Total Incurred  Claim Number
# 0                    1502117.57          2021
# 1                     978660.02           861
# 2                     703986.55           163
# 3                     534232.79           425
# 4                     484143.73           681
# 5                     384687.63          2981
# 6                     384439.93           470
# 7                     344572.38          2908
# 8                     325382.04           157
# 9                     323750.00            38
# 10                    244485.30            59
# 11                    212650.00           226
# 12                    208700.00            70
# 13                    207960.44           101
# 14                    187404.15           226
# 15                    164900.00            69
# 16                    155402.00           369
# 17                    154245.00           454
# 18                    146897.88            69
# 19                    144232.39           104

# %%
Litigatedfy23 = fy23data[fy23data['Attorney Represented'] == 'Y']
Litigated = Litigatedfy23.groupby(['Event of Incident Desc', 'Source of Incident Desc'])[['Disney Claim Total Incurred', 'Claim Number']].agg({'Disney Claim Total Incurred': 'sum', 'Claim Number': 'nunique'}).nlargest(20, 'Claim Number')

# %%
Litigated
Litigated.reset_index(inplace=True)

# %%
IAAPA1 = fy23data[fy23data['Treatment Code (IAAPA) Desc'] == '1 Fatality']
IAAPA2 = fy23data[fy23data['Treatment Code (IAAPA) Desc'] == '2 Serious- Immed Hosp Adm & 24 Hour Stay']
IAAPA3 = fy23data[fy23data['Treatment Code (IAAPA) Desc'] == '3 Other Injury - LT Serious']
IAAPA4 = fy23data[fy23data['Treatment Code (IAAPA) Desc'] == '4 First Aid Only']
IAAPA5 = fy23data[fy23data['Treatment Code (IAAPA) Desc'] == '5 No Treatment']
IAAPA6 = fy23data[fy23data['Treatment Code (IAAPA) Desc'] == '6 Non-Injury Report']

# %%
IAAPA1 = IAAPA1.groupby(['Event of Incident Desc', 'Source of Incident Desc'])[['Disney Claim Total Incurred', 'Claim Number']].agg({'Disney Claim Total Incurred': 'sum', 'Claim Number': 'nunique'}).nlargest(20, 'Claim Number')
IAAPA1
IAAPA1.reset_index(inplace=True)

# %%
IAAPA2 = IAAPA2.groupby(['Event of Incident Desc', 'Source of Incident Desc'])[['Disney Claim Total Incurred', 'Claim Number']].agg({'Disney Claim Total Incurred': 'sum', 'Claim Number': 'nunique'}).nlargest(20, 'Claim Number')
IAAPA2
IAAPA2.reset_index(inplace=True)

# %%
IAAPA3 = IAAPA3.groupby(['Event of Incident Desc', 'Source of Incident Desc'])[['Disney Claim Total Incurred', 'Claim Number']].agg({'Disney Claim Total Incurred': 'sum', 'Claim Number': 'nunique'}).nlargest(20, 'Claim Number')
IAAPA3
IAAPA3.reset_index(inplace=True)

# %%
IAAPA4 = IAAPA4.groupby(['Event of Incident Desc', 'Source of Incident Desc'])[['Disney Claim Total Incurred', 'Claim Number']].agg({'Disney Claim Total Incurred': 'sum', 'Claim Number': 'nunique'}).nlargest(20, 'Claim Number')
IAAPA4
IAAPA4.reset_index(inplace=True)

# %%
IAAPA5 = IAAPA5.groupby(['Event of Incident Desc', 'Source of Incident Desc'])[['Disney Claim Total Incurred', 'Claim Number']].agg({'Disney Claim Total Incurred': 'sum', 'Claim Number': 'nunique'}).nlargest(20, 'Claim Number')
IAAPA5
IAAPA5.reset_index(inplace=True)

# %%
IAAPA6 = IAAPA6.groupby(['Event of Incident Desc', 'Source of Incident Desc'])[['Disney Claim Total Incurred', 'Claim Number']].agg({'Disney Claim Total Incurred': 'sum', 'Claim Number': 'nunique'}).nlargest(20, 'Claim Number')
IAAPA6
IAAPA6.reset_index(inplace=True)

# %%
output_path = r'J:\Data\RMSA Analysis\0 - Team Working Files\10 - Nick\Top_Severity_Litigated_IAAPA_Export.xlsx'

with pd.ExcelWriter(output_path, engine='xlsxwriter') as writer:

    # Write each DataFrame to a different worksheet
    Severity.to_excel(writer, sheet_name='Severity')
    Litigated.to_excel(writer, sheet_name='Litigated')
    IAAPA1.to_excel(writer, sheet_name='IAAPA1')
    IAAPA2.to_excel(writer, sheet_name='IAAPA2')
    IAAPA3.to_excel(writer, sheet_name='IAAPA3')
    IAAPA4.to_excel(writer, sheet_name='IAAPA4')
    IAAPA5.to_excel(writer, sheet_name='IAAPA5')
    IAAPA6.to_excel(writer, sheet_name='IAAPA6')
