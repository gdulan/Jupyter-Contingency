# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from folium.plugins import HeatMap
import gmaps
import gmaps.datasets
import gmaps.geojson_geometries
import gmaps.datasets
import pandas as pd

# %%
gpoints = pd.read_excel('DAKrocksMoneyGpoint.xlsx')
data= gpoints
data
# Out:
#            Location  Incurred                                  Gpoint
# 0           Pandora     63889   28.35557684002944, -81.59216104995737
# 1              Asia     70003  28.359094607343295, -81.58808903874774
# 2            Africa     89134  28.362740307413862, -81.59389551669939
# 3  Discovery Island    161995   28.35748263686716, -81.59058315559795
# 4    Animal Kingdom    126500   28.36138622199534, -81.59056819315813
# 5          Entrance     10503   28.35511456226956, -81.59007384025372
# 6          Dinoland      3500  28.356175146255183, -81.58809924345756
# 7             Oasis      4074   28.35562320484725, -81.59017131647093

# %%
data = np.array([
[28.35557684002944,-81.59216104995737, 63889],
[28.359094607343295,  -81.58808903874774, 70003],
[28.359159858140444, -81.59219287752792, 89134],
[28.35748263686716,  -81.59058315559795, 161995],
[28.36138622199534, -81.59056819315813, 126500],
[28.35511456226956,  -81.59007384025372, 10503],
[28.356175146255183, -81.58809924345756, 3500],
[28.35562320484725, -81.59017131647093, 4074],
])

# %%
m = folium.Map(location=[28.3852, -81.5639], zoom_start=14)

# Convert data into a format that HeatMap can use
heat_data = [[point[0], point[1], point[2]] for point in data]

# Create a HeatMap layer and add it to the map
HeatMap(heat_data).add_to(m)

# Display the map with the heatmap overlay
m.save("magic_kingdom_heatmap.html")

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m = folium.Map(location = [28.350876351096783, -81.59674610916186], tiles ='OpenStreetMap',       
    zoom_start=11)

data = pd.DataFrame({
   'lon':[-81.5205033123493],
   'lat':[28.3674643188715],
   'name':['Moara'],
   'value':[10,]
}, dtype=str)

data

for i in range(0,len(data)):
   folium.Marker(
      location=[data.iloc[i]['lat'], data.iloc[i]['lon']],
      popup=data.iloc[i]['name'],
   ).add_to(m)

# Show the map again
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from folium.plugins import HeatMap
import gmaps
import gmaps.datasets
import gmaps.geojson_geometries
import gmaps.datasets
import pandas as pd

data = np.array([
[28.35557684002944,-81.59216104995737, 63889],
[28.359094607343295,  -81.58808903874774, 70003],
[28.359159858140444, -81.59219287752792, 89134],
[28.35748263686716,  -81.59058315559795, 161995],
[28.36138622199534, -81.59056819315813, 126500],
[28.35511456226956,  -81.59007384025372, 10503],
[28.356175146255183, -81.58809924345756, 3500],
[28.35562320484725, -81.59017131647093, 4074],
])


m = folium.Map(location=[28.3852, -81.5639], zoom_start=14)

heat_data = [[point[0], point[1], point[2]] for point in data]

# Create a custom blue colormap
custom_cmap = branca.colormap.LinearColormap(
    colors=['#0000ff', '#00aaff', '#00ffff', '#00ff00', '#228B22'],  # Blue, Cyan, Neon Green, Forest Green
    index=[0.0, 0.1, 0.2, 0.9, 1.0],
    vmin=0, vmax=1
)

# Create a HeatMap layer with the custom colormap and add it to the map
HeatMap(heat_data, gradient={0.0: '#0000ff', 0.1: '#00aaff', 0.2: '#00ffff', 0.9: '#00ff00', 1.0: '#228B22'}, radius=22).add_to(m)
# Display the map with the heatmap overlay
m.save("magic_kingdom_heatmap.html")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 29
#      26 heat_data = [[point[0], point[1], point[2]] for point in data]
#      28 # Create a custom blue colormap
# ---> 29 custom_cmap = branca.colormap.LinearColormap(
#      30     colors=['#0000ff', '#00aaff', '#00ffff', '#00ff00', '#228B22'],  # Blue, Cyan, Neon Green, Forest Green
#      31     index=[0.0, 0.1, 0.2, 0.9, 1.0],
#      32     vmin=0, vmax=1
#      33 )
#      35 # Create a HeatMap layer with the custom colormap and add it to the map
#      36 HeatMap(heat_data, gradient={0.0: '#0000ff', 0.1: '#00aaff', 0.2: '#00ffff', 0.9: '#00ff00', 1.0: '#228B22'}, radius=22).add_to(m)
#
# NameError: name 'branca' is not defined

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
